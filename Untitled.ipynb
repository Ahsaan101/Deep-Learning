# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import pandas as pd

# %%
#from jupyter_datatables import init_datatables_mode

# %%
#%load_ext jupyter_require
#init_datatables_mode()

# %%
df = pd.read_csv('Bengaluru_House_Data.csv')
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
df = pd.read_csv('Bengaluru_House_Data.csv')
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
df = pd.read_excel("AAPL.xlsx")
df.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2021-08-02  146.360001  146.949997  145.250000  145.520004  144.693344
# 1 2021-08-03  145.809998  148.039993  145.179993  147.360001  146.522888
# 2 2021-08-04  147.270004  147.789993  146.279999  146.949997  146.115219
# 3 2021-08-05  146.979996  147.839996  146.169998  147.059998  146.224594
# 4 2021-08-06  146.350006  147.110001  145.630005  146.139999  145.527512
#
#      Volume
# 0  62880000
# 1  64786600
# 2  56368300
# 3  46397700
# 4  54126800

# %%
import numpy as np

# %%
x = np.arange(2,11).reshape(3,3)
x
# Out:
# array([[ 2,  3,  4],
#        [ 5,  6,  7],
#        [ 8,  9, 10]])

# %%
a = 4
b = 4.5
c = True
d = "hello"

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type(d))
# Out:
# <class 'str'>

# %%
#import modin.pandas as pd

# %%
#import modin.pandas as pd

# %%
df = pd.read_csv("insurance_data.csv")
df
# Out:
#     age  affordibility  bought_insurance
# 0    22              1                 0
# 1    25              0                 0
# 2    47              1                 1
# 3    52              0                 0
# 4    46              1                 1
# 5    56              1                 1
# 6    55              0                 0
# 7    60              0                 1
# 8    62              1                 1
# 9    61              1                 1
# 10   18              1                 0
# 11   28              1                 0
# 12   27              0                 0
# 13   29              0                 0
# 14   49              1                 1
# 15   55              1                 1
# 16   25              0                 1
# 17   58              1                 1
# 18   19              0                 0
# 19   18              1                 0
# 20   21              1                 0
# 21   26              0                 0
# 22   40              1                 1
# 23   45              1                 1
# 24   50              1                 1
# 25   54              1                 1
# 26   23              1                 0
# 27   46              1                 0

# %%
df = pd.read_csv("Bengaluru_House_Data.csv")
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
import numpy as np

# %%
import pandas as pd

# %%
from pandas_dq import dq_report ,Fix_DQ
# Out:
# Imported pandas_dq (1.10). Always upgrade to get latest version.

# %%
df = pd.read_csv("insurance_data.csv")
df.head()
# Out:
#    age  affordibility  bought_insurance
# 0   22              1                 0
# 1   25              0                 0
# 2   47              1                 1
# 3   52              0                 0
# 4   46              1                 1

# %%
dq_report(df, verbose = 1)
fdq = Fix_DQ()
data_transformed = fdq.fit_transform(df)
# Out:
# Alert: Dropping 1 duplicate rows can sometimes cause column data types to change to object. Double-check!
# <style type="text/css">
# #T_ef2bb_row0_col0, #T_ef2bb_row0_col5, #T_ef2bb_row1_col0, #T_ef2bb_row1_col5, #T_ef2bb_row2_col0, #T_ef2bb_row2_col5 {
#   font-family: Segoe UI;
# }
# #T_ef2bb_row0_col1, #T_ef2bb_row1_col1, #T_ef2bb_row1_col2, #T_ef2bb_row1_col3, #T_ef2bb_row1_col4, #T_ef2bb_row2_col1, #T_ef2bb_row2_col2, #T_ef2bb_row2_col3, #T_ef2bb_row2_col4 {
#   background-color: #fff5f0;
#   color: #000000;
#   font-family: Segoe UI;
# }
# #T_ef2bb_row0_col2, #T_ef2bb_row0_col3, #T_ef2bb_row0_col4 {
#   background-color: #67000d;
#   color: #f1f1f1;
#   font-family: Segoe UI;
# }
# </style>
# <table id="T_ef2bb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef2bb_level0_col0" class="col_heading level0 col0" >Data Type</th>
#       <th id="T_ef2bb_level0_col1" class="col_heading level0 col1" >Missing Values%</th>
#       <th id="T_ef2bb_level0_col2" class="col_heading level0 col2" >Unique Values%</th>
#       <th id="T_ef2bb_level0_col3" class="col_heading level0 col3" >Minimum Value</th>
#       <th id="T_ef2bb_level0_col4" class="col_heading level0 col4" >Maximum Value</th>
#       <th id="T_ef2bb_level0_col5" class="col_heading level0 col5" >DQ Issue</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef2bb_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_ef2bb_row0_col0" class="data row0 col0" >int64</td>
#       <td id="T_ef2bb_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_ef2bb_row0_col2" class="data row0 col2" >88</td>
#       <td id="T_ef2bb_row0_col3" class="data row0 col3" >18</td>
#       <td id="T_ef2bb_row0_col4" class="data row0 col4" >62</td>
#       <td id="T_ef2bb_row0_col5" class="data row0 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_ef2bb_level0_row1" class="row_heading level0 row1" >affordibility</th>
#       <td id="T_ef2bb_row1_col0" class="data row1 col0" >int64</td>
#       <td id="T_ef2bb_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_ef2bb_row1_col2" class="data row1 col2" >7</td>
#       <td id="T_ef2bb_row1_col3" class="data row1 col3" >0</td>
#       <td id="T_ef2bb_row1_col4" class="data row1 col4" >1</td>
#       <td id="T_ef2bb_row1_col5" class="data row1 col5" >No issue</td>
#     </tr>
#     <tr>
#       <th id="T_ef2bb_level0_row2" class="row_heading level0 row2" >bought_insurance</th>
#       <td id="T_ef2bb_row2_col0" class="data row2 col0" >int64</td>
#       <td id="T_ef2bb_row2_col1" class="data row2 col1" >0.000000</td>
#       <td id="T_ef2bb_row2_col2" class="data row2 col2" >7</td>
#       <td id="T_ef2bb_row2_col3" class="data row2 col3" >0</td>
#       <td id="T_ef2bb_row2_col4" class="data row2 col4" >1</td>
#       <td id="T_ef2bb_row2_col5" class="data row2 col5" >No issue</td>
#     </tr>
#   </tbody>
# </table>
# Alert: Detecting 1 duplicate rows...
# Alert: Dropping 1 duplicate rows can sometimes cause column data types to change to object. Double-check!

# %%
df.dtypes
# Out:
# age                 int64
# affordibility       int64
# bought_insurance    int64
# dtype: object

# %%
df = pd.read_csv("Bengaluru_House_Data.csv")
df.head()
# Out:
#               area_type   availability                  location       size  \
# 0  Super built-up  Area         19-Dec  Electronic City Phase II      2 BHK
# 1            Plot  Area  Ready To Move          Chikka Tirupathi  4 Bedroom
# 2        Built-up  Area  Ready To Move               Uttarahalli      3 BHK
# 3  Super built-up  Area  Ready To Move        Lingadheeranahalli      3 BHK
# 4  Super built-up  Area  Ready To Move                  Kothanur      2 BHK
#
#    society total_sqft  bath  balcony   price
# 0  Coomee        1056   2.0      1.0   39.07
# 1  Theanmp       2600   5.0      3.0  120.00
# 2      NaN       1440   2.0      3.0   62.00
# 3  Soiewre       1521   3.0      1.0   95.00
# 4      NaN       1200   2.0      1.0   51.00

# %%
df.dtypes
# Out:
# area_type        object
# availability     object
# location         object
# size             object
# society          object
# total_sqft       object
# bath            float64
# balcony         float64
# price           float64
# dtype: object

# %%
df.tail()
# Out:
#                   area_type   availability               location       size  \
# 13315        Built-up  Area  Ready To Move             Whitefield  5 Bedroom
# 13316  Super built-up  Area  Ready To Move          Richards Town      4 BHK
# 13317        Built-up  Area  Ready To Move  Raja Rajeshwari Nagar      2 BHK
# 13318  Super built-up  Area         18-Jun        Padmanabhanagar      4 BHK
# 13319  Super built-up  Area  Ready To Move           Doddathoguru      1 BHK
#
#        society total_sqft  bath  balcony  price
# 13315  ArsiaEx       3453   4.0      0.0  231.0
# 13316      NaN       3600   5.0      NaN  400.0
# 13317  Mahla T       1141   2.0      1.0   60.0
# 13318  SollyCl       4689   4.0      1.0  488.0
# 13319      NaN        550   1.0      1.0   17.0

# %%
df.columns
# Out:
# Index(['area_type', 'availability', 'location', 'size', 'society',
#        'total_sqft', 'bath', 'balcony', 'price'],
#       dtype='object')

# %%
df.ndim
# Out:
# 2

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=13320, step=1),
#  Index(['area_type', 'availability', 'location', 'size', 'society',
#         'total_sqft', 'bath', 'balcony', 'price'],
#        dtype='object')]

# %%
df.values
# Out:
# array([['Super built-up  Area', '19-Dec', 'Electronic City Phase II',
#         ..., 2.0, 1.0, 39.07],
#        ['Plot  Area', 'Ready To Move', 'Chikka Tirupathi', ..., 5.0, 3.0,
#         120.0],
#        ['Built-up  Area', 'Ready To Move', 'Uttarahalli', ..., 2.0, 3.0,
#         62.0],
#        ...,
#        ['Built-up  Area', 'Ready To Move', 'Raja Rajeshwari Nagar', ...,
#         2.0, 1.0, 60.0],
#        ['Super built-up  Area', '18-Jun', 'Padmanabhanagar', ..., 4.0,
#         1.0, 488.0],
#        ['Super built-up  Area', 'Ready To Move', 'Doddathoguru', ...,
#         1.0, 1.0, 17.0]], dtype=object)

# %%
df.mean()
# Out:
# bath         2.692610
# balcony      1.584376
# price      112.565627
# dtype: float64

# %%
df.bath.mean()
# Out:
# 2.6926096474673513

# %%
df.location[:5]
# Out:
# 0    Electronic City Phase II
# 1            Chikka Tirupathi
# 2                 Uttarahalli
# 3          Lingadheeranahalli
# 4                    Kothanur
# Name: location, dtype: object

# %%
df.bath.count()
# Out:
# 13247

# %%
df_location = df.groupby(['location'])
df_location

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 2            Built-up  Area  Ready To Move               Uttarahalli
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 4      Super built-up  Area  Ready To Move                  Kothanur
# ...                     ...            ...                       ...
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13316  Super built-up  Area  Ready To Move             Richards Town
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
# 13319  Super built-up  Area  Ready To Move              Doddathoguru
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 2          3 BHK      NaN       1440   2.0      3.0   62.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 4          2 BHK      NaN       1200   2.0      1.0   51.00
# ...          ...      ...        ...   ...      ...     ...
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13316      4 BHK      NaN       3600   5.0      NaN  400.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
# 13319      1 BHK      NaN        550   1.0      1.0   17.00
#
# [13320 rows x 9 columns]

# %%
df.nunique()
# Out:
# area_type          4
# availability      81
# location        1305
# size              31
# society         2688
# total_sqft      2117
# bath              19
# balcony            4
# price           1994
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 529

# %%
df.isnull().sum()
# Out:
# area_type          0
# availability       0
# location           1
# size              16
# society         5502
# total_sqft         0
# bath              73
# balcony          609
# price              0
# dtype: int64

# %%
df.drop_duplicates(inplace = True)
df.duplicated().sum()
# Out:
# 0

# %%
df.dropna(inplace = True)
df.isnull().sum()
# Out:
# area_type       0
# availability    0
# location        0
# size            0
# society         0
# total_sqft      0
# bath            0
# balcony         0
# price           0
# dtype: int64

# %%
df
# Out:
#                   area_type   availability                  location  \
# 0      Super built-up  Area         19-Dec  Electronic City Phase II
# 1                Plot  Area  Ready To Move          Chikka Tirupathi
# 3      Super built-up  Area  Ready To Move        Lingadheeranahalli
# 5      Super built-up  Area  Ready To Move                Whitefield
# 11               Plot  Area  Ready To Move                Whitefield
# ...                     ...            ...                       ...
# 13308        Built-up  Area  Ready To Move         Bannerghatta Road
# 13314  Super built-up  Area  Ready To Move         Green Glen Layout
# 13315        Built-up  Area  Ready To Move                Whitefield
# 13317        Built-up  Area  Ready To Move     Raja Rajeshwari Nagar
# 13318  Super built-up  Area         18-Jun           Padmanabhanagar
#
#             size  society total_sqft  bath  balcony   price
# 0          2 BHK  Coomee        1056   2.0      1.0   39.07
# 1      4 Bedroom  Theanmp       2600   5.0      3.0  120.00
# 3          3 BHK  Soiewre       1521   3.0      1.0   95.00
# 5          2 BHK  DuenaTa       1170   2.0      1.0   38.00
# 11     4 Bedroom  Prrry M       2785   5.0      3.0  295.00
# ...          ...      ...        ...   ...      ...     ...
# 13308      3 BHK  Baanise       1527   3.0      1.0  142.00
# 13314      3 BHK  SoosePr       1715   3.0      3.0  112.00
# 13315  5 Bedroom  ArsiaEx       3453   4.0      0.0  231.00
# 13317      2 BHK  Mahla T       1141   2.0      1.0   60.00
# 13318      4 BHK  SollyCl       4689   4.0      1.0  488.00
#
# [7144 rows x 9 columns]
